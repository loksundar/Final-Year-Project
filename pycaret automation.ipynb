# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from scipy import stats
from mlxtend.preprocessing import minmax_scaling

# %%
from gtts import gTTS
from playsound import playsound
import os
import pyttsx3
engine = pyttsx3.init()
newVoiceRate = 150
engine.setProperty('rate',newVoiceRate)
vid = "HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0"
engine.setProperty('voice', vid)

# %%
from pycaret.classification import *

# %%
#engine.say("LGBMClassifier(boosting_type='gbdt',")
#engine.runAndWait()

# %%
#x = pd.DataFrame(setting_up)

# %%
# https://pycaret.org/preprocessing/

# %%
a = compare_models(exclude = ['catboost'], sort = 'AUC',n_select=3)
# Out:
# <style  type="text/css" >
#     #T_e0c81279_8570_11eb_b10d_94b86da6f553 th {
#           text-align: left;
#     }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row0_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row0_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row0_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row0_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row1_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row1_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row1_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row1_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row1_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row1_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row1_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row1_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row2_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row2_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row2_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row2_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row2_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row2_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row2_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row2_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row3_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row3_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row3_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row3_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row3_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row3_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row3_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row3_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row4_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row5_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row5_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e0c81279_8570_11eb_b10d_94b86da6f553row5_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;

# %%
model1 = a[0]
model2 = a[1]
model3 = a[2]

# %%
strn = "The Top 3 models which performes best on the data are:  1 "+str(model1).split()[0].split("(")[0]+". 2 "+str(model2).split()[0].split("(")[0]+". 3 "+str(model3).split()[0].split("(")[0]
engine.say(strn)
engine.runAndWait()

# %%
str(model1).split()[0].split("(")[0]
# Out:
# 'LGBMClassifier'

# %%
str(model2).split()[0]
# Out:
# 'GradientBoostingClassifier(ccp_alpha=0.0,'

# %%
str(model3).split()[0]
# Out:
# "AdaBoostClassifier(algorithm='SAMME.R',"

# %%
df=pd.read_csv("train.csv")
target = 'Response'
dtypedf = pd.DataFrame()
if(1==1):
    dtypedf['Feature'] = df.dtypes.index
    dtypedf['dtype'] = [str(x) for x in df.dtypes]
    numdf = df.loc[:,df.dtypes!=np.object]
    catdf = df.loc[:,df.dtypes==np.object]
    strn="There are xy Numerical features in dataframe. "
    strn = strn.replace("xy",str(len(numdf.columns)))
    engine.say(strn)
    engine.runAndWait()
    strn="There are xy Categorical features in dataframe. "
    strn = strn.replace("xy",str(len(catdf.columns)))
    engine.say(strn)
    engine.runAndWait()
    for i in numdf.columns:
        df[i].fillna(df[i].mean(skipna=True),inplace=True)
    for i in catdf.columns:
        df[i].fillna(df[i].mode()[0],inplace=True)
    for i in catdf.columns:
        le = LabelEncoder()
        le.fit(df[i])
        df[i]= pd.Series(le.transform(df[i]))
    for i in numdf.columns:
        df[i]=minmax_scaling(df[i], columns = [0])
    x = pd.DataFrame(setup(data = df, target = target, session_id=123,silent=True))
    j=0
    for i in range(len(x[0])):
        try:
            if(x[0][i][0][0]=="Setup Config"):
                j=i
        except:
            pass
    setting_up = pd.DataFrame(setup(data = df, target = target, session_id=123,silent=True))[0][j][0][1]
    strn = "There is a imbalance in the data. to fix this we are using "+str(setting_up.set_index("Description").loc['Fix Imbalance Method'][0])+" method."
    engine.say(strn)
    engine.runAndWait()
    strn="The Data-Scibot is running data on all the Models So Please wait for 2 minutes"
    engine.say(strn)
    engine.runAndWait()
    a = compare_models(exclude = ['catboost'], sort = 'AUC',n_select=3)
    model1 = a[0]
    model2 = a[1]
    model3 = a[2]
    strn = "The Top 3 models which performes best on the data are:  ."+str(model1).split()[0].split("(")[0]+".  "+str(model2).split()[0].split("(")[0]+".  "+str(model3).split()[0].split("(")[0]
    engine.say(strn)
    engine.runAndWait()

# %%
Scibot("train_Response.csv","Response","AUC")
# Out:
# <style  type="text/css" >
#     #T_9e10c22c_895b_11eb_b481_94b86da6f553 th {
#           text-align: left;
#     }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row0_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row0_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row0_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row0_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row1_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row1_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row1_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row1_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row1_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row1_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row1_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row1_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row2_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row2_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row2_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row2_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row2_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row2_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row2_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row2_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row3_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row3_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row3_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row3_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row3_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row3_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row3_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row3_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row4_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row5_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row5_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9e10c22c_895b_11eb_b481_94b86da6f553row5_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;

# %%
df.shape[1]
# Out:
# 14

# %%
def Scibot(filen,target,measure):
    import numpy as np
    import pandas as pd
    from sklearn.preprocessing import LabelEncoder
    from scipy import stats
    from mlxtend.preprocessing import minmax_scaling
    import pyttsx3
    engine = pyttsx3.init()
    newVoiceRate = 150
    engine.setProperty('rate',newVoiceRate)
    vid = "HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0"
    engine.setProperty('voice', vid)
    df=pd.read_csv(filen)
    target = str(target)
    dtypedf = pd.DataFrame()
    dtypedf['Feature'] = df.dtypes.index
    dtypedf['dtype'] = [str(x) for x in df.dtypes]
    numdf = df.loc[:,df.dtypes!=np.object]
    catdf = df.loc[:,df.dtypes==np.object]
    strn="There are "+str(df.shape[0])+" rows and "+str(df.shape[1])+"columns in the Data. "
    strn=strn + " There are xy Numerical features in dataframe. "
    strn = strn.replace("xy",str(len(numdf.columns)))
    engine.say(strn)
    strn="There are xy Categorical features in dataframe. "
    strn = strn.replace("xy",str(len(catdf.columns)))
    engine.say(strn)
    if(df.isnull().sum().sum()>0):
        strn = "There are "+str(df.isnull().sum().sum())+" Missing values in the data. Which will be Replaced by Mean Mode Imputaion Method."
        engine.say(strn)
    else:
        strn = "There are no Missing values in data"
        engine.say(strn)
    for i in numdf.columns:
        df[i].fillna(df[i].mean(skipna=True),inplace=True)
    for i in catdf.columns:
        df[i].fillna(df[i].mode()[0],inplace=True)
    for i in catdf.columns:
        le = LabelEncoder()
        le.fit(df[i])
        df[i]= pd.Series(le.transform(df[i]))
    for i in numdf.columns:
        df[i]=minmax_scaling(df[i], columns = [0])
    x = pd.DataFrame(setup(data = df, target = target, session_id=123,silent=True))
    j=0
    for i in range(len(x[0])):
        try:
            if(x[0][i][0][0]=="Setup Config"):
                j=i
        except:
            pass
    setting_up = pd.DataFrame(setup(data = df, target = target, session_id=123,silent=True))[0][j][0][1]
    strn = "There is a imbalance in the data. to fix this we are using "+str(setting_up.set_index("Description").loc['Fix Imbalance Method'][0])+" method."
    engine.say(strn)
    strn="The Data-Scibot is running data on all the Models So Please wait for 2 minutes"
    engine.say(strn)
    engine.runAndWait()
    a = compare_models(exclude = ['catboost'], sort = str(measure),n_select=3)
    model1 = a[0]
    model2 = a[1]
    model3 = a[2]
    strn = "The Top 3 models which performes best on the data are:  ."+str(model1).split()[0].split("(")[0]+".  "+str(model2).split()[0].split("(")[0]+".  "+str(model3).split()[0].split("(")[0]
    engine.say(strn)
    engine.runAndWait()

# %%
class Datascibot:
    df = 1
    def __init__(self):
        import numpy as np
        import pandas as pd
        from sklearn.preprocessing import LabelEncoder
        from scipy import stats
        from mlxtend.preprocessing import minmax_scaling
        import pyttsx3
        engine = pyttsx3.init()
        newVoiceRate = 150
        engine.setProperty('rate',newVoiceRate)
        vid = "HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0"
        engine.setProperty('voice', vid)
    def analyze(filen,target,measure):
        df=pd.read_csv(filen)
        target = str(target)
        dtypedf = pd.DataFrame()
        dtypedf['Feature'] = df.dtypes.index
        dtypedf['dtype'] = [str(x) for x in df.dtypes]
        numdf = df.loc[:,df.dtypes!=np.object]
        catdf = df.loc[:,df.dtypes==np.object]
        strn="There are xy Numerical features in dataframe. "
        strn = strn.replace("xy",str(len(numdf.columns)))
        engine.say(strn)
        engine.runAndWait()
        strn="There are xy Categorical features in dataframe. "
        strn = strn.replace("xy",str(len(catdf.columns)))
        engine.say(strn)
        engine.runAndWait()
        if(df.isnull().sum().sum()>0):
            strn = "There are "+str(df.isnull().sum().sum())+" Missing values in the data. Which will be Replaced by Mean Mode Imputaion Method."
            engine.say(strn)
            engine.runAndWait()
        for i in numdf.columns:
            df[i].fillna(df[i].mean(skipna=True),inplace=True)
        for i in catdf.columns:
            df[i].fillna(df[i].mode()[0],inplace=True)
        for i in catdf.columns:
            le = LabelEncoder()
            le.fit(df[i])
            df[i]= pd.Series(le.transform(df[i]))
        for i in numdf.columns:
            df[i]=minmax_scaling(df[i], columns = [0])
        x = pd.DataFrame(setup(data = df, target = target, session_id=123,silent=True))
        j=0
        for i in range(len(x[0])):
            try:
                if(x[0][i][0][0]=="Setup Config"):
                    j=i
            except:
                pass
        setting_up = pd.DataFrame(setup(data = df, target = target, session_id=123,silent=True))[0][j][0][1]
        strn = "There is a imbalance in the data. to fix this we are using "+str(setting_up.set_index("Description").loc['Fix Imbalance Method'][0])+" method."
        engine.say(strn)
        engine.runAndWait()
        strn="The Data-Scibot is running data on all the Models So Please wait for 2 minutes"
        engine.say(strn)
        engine.runAndWait()
        a = compare_models(exclude = ['catboost'], sort = str(measure),n_select=3)
        model1 = a[0]
        model2 = a[1]
        model3 = a[2]
        strn = "The Top 3 models which performes best on the data are:  ."+str(model1).split()[0].split("(")[0]+".  "+str(model2).split()[0].split("(")[0]+".  "+str(model3).split()[0].split("(")[0]
        engine.say(strn)
        engine.runAndWait()

# %%
a = Datascibot()

# %%
a.df
# Out:
# 1
