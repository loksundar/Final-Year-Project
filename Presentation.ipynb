# %%
import Datascibot.scibot as ds

# %%
a = ds.scibot.analyze("train.csv","Is_Lead","AUC")
# Out:
# <style  type="text/css" >
# </style><table id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row1_col1" class="data row1 col1" >Is_Lead</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row3_col1" class="data row3 col1" >0.0: 0, 1.0: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row4_col1" class="data row4 col1" >(245725, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row6_col1" class="data row6 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row11_col1" class="data row11 col1" >(172007, 10)</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row12_col1" class="data row12 col1" >(73718, 10)</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_a4c5a060_bfe8_11eb_9057_94b86da6f553row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-c15e8f896f83> in <module>
# ----> 1 a = ds.scibot.analyze("train.csv","Is_Lead","AUC")
#
# ~\Google Drive\Final Year Project\Datascibot\scibot.py in analyze(filen, target, measure)
#      54         for i in numdf.columns:
#      55             df[i]=minmax_scaling(df[i], columns = [0])
# ---> 56         x = pd.DataFrame(setup(data = df, target = target, session_id=123,silent=True))
#      57         j=0
#      58         for i in range(len(x[0])):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     472                     if is_named_tuple(data[0]) and columns is None:
#     473                         columns = data[0]._fields
# --> 474                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     475                     columns = ensure_index(columns)
#     476
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     459         return [], []  # columns if columns is not None else []
#     460     if isinstance(data[0], (list, tuple)):
# --> 461         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     462     elif isinstance(data[0], abc.Mapping):
#     463         return _list_of_dict_to_arrays(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     491     else:
#     492         # list of lists
# --> 493         content = list(lib.to_object_array(data).T)
#     494     # gh-26429 do not raise user-facing AssertionError
#     495     try:
#
# pandas\_libs\lib.pyx in pandas._libs.lib.to_object_array()
#
# TypeError: object of type 'MLUsecase' has no len()

# %%
a[0].isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# Accuracy  AUC   Recall  Prec.   F1

# %%
#data_target
#emp_Attrition
#phishing_class
#train_Response
#train_subscribed

# %%
x = {"data_target.csv":"target","emp_Attrition.csv":"Attrition","phishing_class.csv":"class",
     "train_Response.csv":"Response","train_subscribed.csv":"subscribed"}

# %%
for i in x:
    ds.scibot.analyze(i,x[i],"Accuracy")
# Out:
# <style  type="text/css" >
#     #T_ae775822_88a0_11eb_92ee_94b86da6f553 th {
#           text-align: left;
#     }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col7 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row1_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row1_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row1_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row1_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row1_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row1_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row1_col7 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row1_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row2_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row2_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row2_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row2_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row2_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row2_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row2_col7 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row2_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row3_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row3_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row3_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row3_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row3_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row3_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row3_col7 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row3_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row4_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row4_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row4_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row5_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row5_col4 {
#             text-align:  left;
#             text-align:  left;
#             :

# %%
188+374+188
# Out:
# 750

# %%
import random

print(random.randint(0,6))
# Out:
# 1

# %%
print(random.randint(1,5))
print(random.randint(1,5))
print(random.randint(1,5))
print(random.randint(1,5))
print(random.randint(1,5))
# Out:
# 5
# 3
# 2
# 4
# 3
