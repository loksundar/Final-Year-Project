# %%
import Datascibot.scibot as ds

# %%
a = ds.scibot.analyze("data_target.csv","target","Prec.")
# Out:
# <style  type="text/css" >
#     #T_87f6136c_8962_11eb_80a9_94b86da6f553 th {
#           text-align: left;
#     }    #T_87f6136c_8962_11eb_80a9_94b86da6f553row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_87f6136c_8962_11eb_80a9_94b86da6f553row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87f6136c_8962_11eb_80a9_94b86da6f553row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_87f6136c_8962_11eb_80a9_94b86da6f553row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87f6136c_8962_11eb_80a9_94b86da6f553row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_87f6136c_8962_11eb_80a9_94b86da6f553row0_col5 {
#             text-align:  left;
# ...

# %%
a[0].isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# Accuracy  AUC   Recall  Prec.   F1

# %%
#data_target
#emp_Attrition
#phishing_class
#train_Response
#train_subscribed

# %%
x = {"data_target.csv":"target","emp_Attrition.csv":"Attrition","phishing_class.csv":"class",
     "train_Response.csv":"Response","train_subscribed.csv":"subscribed"}

# %%
for i in x:
    ds.scibot.analyze(i,x[i],"Accuracy")
# Out:
# <style  type="text/css" >
#     #T_ae775822_88a0_11eb_92ee_94b86da6f553 th {
#           text-align: left;
#     }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_ae775822_88a0_11eb_92ee_94b86da6f553row0_col5 {
# ...
